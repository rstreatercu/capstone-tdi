# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import matplotlib as plt
import matplotlib.pyplot

# %%
data = pd.read_csv('Data.csv')
# Remove universities with identical names before setting index to name
data.drop_duplicates(subset="instnm",inplace=True)
data.set_index("instnm",inplace=True)

# %%
r2_min = 0.85 # Limit for determining linearity

# %%
# Multiple formats used in column names- save all fiscal years to enrollment DataFrame.
enroll_col_names = ["Grand total (EF{:}  All students total)".format(i) for i in range(2001,2004)] + ["Grand total (EF{:}_RV  All students total)".format(i) for i in range(2004,2019)] + ["Grand total (EF{:}  All students total)".format(i) for i in range(2019,2021)]
enrollment_list = pd.DataFrame(data[enroll_col_names])
enrollment_list.dropna(inplace=True)
# Ignore schools that had less than 200 enrollment in 2001 so that larger schools are represented
enrollment_list = enrollment_list[enrollment_list["Grand total (EF2001  All students total)"]>=200]
# Create DataFrame of expected 2020 enrollments
enroll_project = pd.DataFrame(enrollment_list["Grand total (EF2020  All students total)"])
enroll_project["Projected 2020 enrollment"] = 0
for i in enrollment_list.index:
    # Start at fourth point from the end so that there are at least four points available, then search more points
    # to determine when the data stops being linear.
    for j in reversed(range(0,len(enrollment_list.loc[i])-4)):
        # Find out when r^2 value is invalid (data not linear)
        year_range = [n for n in range(j,len(enrollment_list.loc[i])-1)]
        cor = np.corrcoef(year_range, enrollment_list.loc[i][year_range])
        r2 = cor[0,1]**2
        if r2 < r2_min:
            # Remove point that leads to bad r2 value
            year_range = year_range[1:]
            break
    if (len(year_range) == 3):
        # Remove enrollments without clear trends
        enrollment_list.drop(index=i, inplace=True)
        continue;
    p = np.polyfit(year_range, enrollment_list.loc[i][year_range],1)
    enroll_project["Projected 2020 enrollment"].loc[i] = p[0] * 19 + p[1]
    # plot a few random lines
    if (i == enrollment_list.index[0]) or (i == enrollment_list.index[500]) or (i == enrollment_list.index[1000]):
        plt.pyplot.plot(range(year_range[0],20),range(year_range[0],20)*p[0]+p[1])
        plt.pyplot.scatter(range(0,20),enrollment_list.loc[i])
plt.pyplot.legend([enrollment_list.index[0],enrollment_list.index[500],enrollment_list.index[1000]])
enroll_diff_frac = (enroll_project["Grand total (EF2020  All students total)"] - enroll_project["Projected 2020 enrollment"])/enroll_project["Grand total (EF2020  All students total)"]

# %%
# Drop outliers from enroll difference- came from errors in the forcasting
enroll_diff_frac = enroll_diff_frac[abs(enroll_diff_frac)<1]
corr_df = pd.DataFrame(data.loc[enroll_diff_frac.index])
corr_df["Enroll difference"] = enroll_diff_frac
corr_df.dropna(inplace=True,subset=["Enroll difference","Student-to-faculty ratio (EF2019D)","Percent of full-time first-time undergraduates awarded any financial aid (SFA1920)"])
corr_df.corr()
plt.pyplot.scatter(corr_df["Institutional support - Current year total (F1920_F1A)"],corr_df["Enroll difference"])

# %%
corr_df.corr()["Enroll difference"].to_string()
# Out:
# 'Grand total (GR2020  4-year institutions  Adjusted cohort (revised cohort minus exclusions))                               0.066271\nAverage net price (income 0-30 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)                    -0.000209\nAverage net price (income 30 001-48 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)               -0.028383\nAverage net price (income 48 001-75 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)               -0.044283\nAverage net price (income 75 001-110 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)              -0.078524\nAverage net price (income over 110 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)                -0.152940\nPercent of full-time first-time undergraduates awarded any financial aid (SFA1920)                                         0.116854\nPercent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1920)          0.090998\nAverage amount of federal  state  local or institutional grant aid awarded (SFA1920)                                       0.015388\nLevel of institution (HD2020)                                                                                             -0.076826\nInstitution size category (HD2020)                                                                                         0.007531\nInstitutional category (HD2020)                                                                                           -0.073327\nPercent admitted - total (DRVADM2020)                                                                                      0.026648\nAdmissions yield - total (DRVADM2020)                                                                                      0.149947\nAdult age (25-64) enrollment  undergraduate (DRVEF2020)                                                                    0.155682\nTotal  enrollment (DRVEF2020)                                                                                              0.112806\nPercent of undergraduate enrollment 18-24 (DRVEF2020)                                                                      0.032132\nPercent of undergraduate enrollment  25-64 (DRVEF2020)                                                                    -0.000247\nFull-time retention rate  2020 (EF2020D)                                                                                   0.107826\nTotal entering students at the undergraduate level  fall 2020 (EF2020D)                                                    0.127761\nStudent-to-faculty ratio (EF2020D)                                                                                         0.079214\nSalaries and wages for core expenses as a percent of total core expenses (GASB) (DRVF2020)                                -0.006175\nSalaries and wages for instruction as a percent of total expenses for instruction (GASB) (DRVF2020)                       -0.033545\nSalaries and wages for research as a percent of total expenses for research (GASB) (DRVF2020)                             -0.009609\nSalaries and wages for public service as a percent of total expenses for public service (GASB) (DRVF2020)                  0.001839\nSalaries and wages for academic support as a percent of total expenses for academic support (GASB) (DRVF2020)             -0.106865\nSalaries and wages for student services as a percent of total expenses for student services (GASB) (DRVF2020)             -0.087038\nSalaries and wages for institutional support as a percent of total expenses for institutional support (GASB) (DRVF2020)   -0.031772\nAdult age (25-64) enrollment  undergraduate (DRVEF2019)                                                                    0.057985\nTotal  enrollment (DRVEF2019)                                                                                              0.053810\nPercent o ...

# %%
corr_df.corr()["Full-time retention rate  2020 (EF2020D)"].to_string()
# Out:
# 'Grand total (GR2020  4-year institutions  Adjusted cohort (revised cohort minus exclusions))                               0.393238\nAverage net price (income 0-30 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)                    -0.099391\nAverage net price (income 30 001-48 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)               -0.142351\nAverage net price (income 48 001-75 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)               -0.029326\nAverage net price (income 75 001-110 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)               0.103536\nAverage net price (income over 110 000)-students awarded Title IV federal financial aid  2019-20 (SFA1920)                 0.458454\nPercent of full-time first-time undergraduates awarded any financial aid (SFA1920)                                        -0.042317\nPercent of full-time first-time undergraduates awarded federal  state  local or institutional grant aid (SFA1920)         -0.049827\nAverage amount of federal  state  local or institutional grant aid awarded (SFA1920)                                       0.464888\nLevel of institution (HD2020)                                                                                             -0.417981\nInstitution size category (HD2020)                                                                                         0.329209\nInstitutional category (HD2020)                                                                                           -0.390975\nPercent admitted - total (DRVADM2020)                                                                                     -0.288164\nAdmissions yield - total (DRVADM2020)                                                                                      0.005876\nAdult age (25-64) enrollment  undergraduate (DRVEF2020)                                                                   -0.026038\nTotal  enrollment (DRVEF2020)                                                                                              0.272362\nPercent of undergraduate enrollment 18-24 (DRVEF2020)                                                                      0.604228\nPercent of undergraduate enrollment  25-64 (DRVEF2020)                                                                    -0.460524\nFull-time retention rate  2020 (EF2020D)                                                                                   1.000000\nTotal entering students at the undergraduate level  fall 2020 (EF2020D)                                                    0.209188\nStudent-to-faculty ratio (EF2020D)                                                                                        -0.120978\nSalaries and wages for core expenses as a percent of total core expenses (GASB) (DRVF2020)                                 0.003088\nSalaries and wages for instruction as a percent of total expenses for instruction (GASB) (DRVF2020)                       -0.034244\nSalaries and wages for research as a percent of total expenses for research (GASB) (DRVF2020)                             -0.134739\nSalaries and wages for public service as a percent of total expenses for public service (GASB) (DRVF2020)                  0.054199\nSalaries and wages for academic support as a percent of total expenses for academic support (GASB) (DRVF2020)             -0.198407\nSalaries and wages for student services as a percent of total expenses for student services (GASB) (DRVF2020)             -0.213443\nSalaries and wages for institutional support as a percent of total expenses for institutional support (GASB) (DRVF2020)    0.145634\nAdult age (25-64) enrollment  undergraduate (DRVEF2019)                                                                   -0.040963\nTotal  enrollment (DRVEF2019)                                                                                              0.271930\nPercent o ...

# %%
plt.pyplot.scatter(corr_df["Percent of undergraduate enrollment  25-64 (DRVEF2020)"],corr_df["Full-time retention rate  2020 (EF2020D)"])
